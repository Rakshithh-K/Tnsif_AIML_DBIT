# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing
california_housing=fetch_california_housing()
data=pd.DataFrame(california_housing.data,columns=california_housing.feature_names)
data['MedVal']=california_housing.target
#plt.figure(figsize(10,15))
data.hist(bins=30,figsize=(19,17))
plt.title('hel')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing
california_housing=fetch_california_housing()
data=pd.DataFrame(california_housing.data,columns=california_housing.feature_names)
data['MedVal']=california_housing.target
correlation_matrix=data.corr()
print("correlaion matrix")
print(correlation_matrix)
plt.figure(figsize=(18,6))
sns.heatmap(correlation_matrix,cmap='coolwarm',annot=True,fmt='.2f',linewidth=0.5)
plt.show()
# Out:
# correlaion matrix
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedVal      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude    MedVal
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

iris=load_iris()
data=iris.data
label=iris.target
label_names=iris.target_names

df=pd.DataFrame(data,columns=iris.feature_names)

pca=PCA(n_components=2)

datared=pca.fit_transform(data)

reduced_df=pd.DataFrame(datared,columns=['principle component 1','principle component 2'])
reduced_df['Label']=labels

plt.figure(figsize=(10,15))
colors=['r','g','b']
for i,label in enumerate(np.unique(labels)):
    plt.scatter(
        reduced_df[reduced_df['Label'] == label]['Principal Component 1'],
        reduced_df[reduced_df['Label'] == label]['Principal Component 2'],
        label=label_names[label],
        color=colors[i]
    )
plt.title('ihfgehif')
plt.xlabel('pca 1')
plt.ylabel('pca 2')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 19
#      16 datared=pca.fit_transform(data)
#      18 reduced_df=pd.DataFrame(datared,columns=['principle component 1','principle component 2'])
# ---> 19 reduced_df['Label']=labels
#      21 plt.figure(figsize=(10,15))
#      22 colors=['r','g','b']
#
# NameError: name 'labels' is not defined
